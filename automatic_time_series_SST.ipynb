# %%
# Author: Arthur Prigent
# Email: aprigent@ictp.it

#### DATA ####
# https://downloads.psl.noaa.gov/Datasets/
from functions import *
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image
# Out:
# 2026-02-16 21:58:33.044085

# %% [markdown]
# # SST anomalies timeseries

# %% [markdown]
# # [Monthly timeseries](#monthly)

# %% [markdown]
# # Zonal wind anomalies timeseries

# %% [markdown]
# # [Monthly timeseries](#monthly_u)

# %% [markdown]
# # WAMOI
#
# ## [West African Monsoon Onset](#test)

# %% [markdown]
# # ACT
# ## [Atlantic Cold Tongue Onset](#test3)

# %% [markdown]
# # AMM
# ## [Atlantic Meridional mode index](#test2)

# %% [markdown]
# # AMO
# ## [Atlantic Multi-decadal Oscillation](#test4)

# %% [markdown]
# # St Helena SLP index
# ## [SLP index](#test5)

# %% [markdown]
# # [Identification of Atlantic Niños/Niños and Benguela Niños/Niñas](#test9)

# %% [markdown]
# # PIRATA data

# %% [markdown]
# # [Temperature PIRATA 23˚W, 10˚W, 0˚E ](./plot_daily_PIRATA.html)

# %% [markdown]
# # [Canonical/Non-canonical Atlantic Niños](#test6)

# %% [markdown]
# # [Indian Ocean Dipole](#test7)

# %% [markdown]
# # [Seasonal forecast CFSv2](#test8)

# %% [markdown]
# # References
# # [link](#test20)

# %% [markdown]
# # Regions of interests

# %%
Image(filename='fig_boxes_map.png')

# %% [markdown]
# # Last update

# %%
print(str(now)[:16])
# Out:
# 2026-02-16 21:43

# %% [markdown]
# # Read SST data

# %%
path_data = 'http://psl.noaa.gov/thredds/dodsC/Datasets/COBE2/sst.mon.mean.nc'
(ssta_atl3_norm_cobe,ssta_aba_norm_cobe,
 ssta_nino34_norm_cobe,ssta_dni_norm_cobe,
 ssta_cni_norm_cobe,ssta_nni_norm_cobe,iod_cobe) = read_data_compute_anomalies(path_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 path_data = 'http://psl.noaa.gov/thredds/dodsC/Datasets/COBE2/sst.mon.mean.nc'
#       2 (ssta_atl3_norm_cobe,ssta_aba_norm_cobe,
#       3  ssta_nino34_norm_cobe,ssta_dni_norm_cobe,
# ----> 4  ssta_cni_norm_cobe,ssta_nni_norm_cobe,iod_cobe) = read_data_compute_anomalies(path_data)
#
# File ~/Documents/Postdoc_ICTP/Projects/ATL3_ABA_SSTa-main/functions.py:264, in read_data_compute_anomalies(path_data)
#     262 ds = xr.open_dataset(path_data,engine='pydap')
#     263 sst= ds.sst.sel(time=slice(datetime.datetime(1982, 1, 1), now))
# --> 264 sst = xr.concat([sst[:, :, 180:], sst[:, :, :180]], dim='lon')
#     265 sst.coords['lon'] = (sst.coords['lon'] + 180) % 360 - 180
#     268 ## Make sub areas ##
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/concat.py:240, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     235     raise ValueError(
#     236         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     237     )
#     239 if isinstance(first_obj, DataArray):
# --> 240     return _dataarray_concat(
#     241         objs,
#     242         dim=dim,
#     243         data_vars=data_vars,
#     244         coords=coords,
#     245         compat=compat,
#     246         positions=positions,
#     247         fill_value=fill_value,
#     248         join=join,
#     249         combine_attrs=combine_attrs,
#     250     )
#     251 elif isinstance(first_obj, Dataset):
#     252     return _dataset_concat(
#     253         objs,
#     254         dim=dim,
#    (...)
#     261         combine_attrs=combine_attrs,
#     262     )
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/concat.py:712, in _dataarray_concat(arrays, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     709             arr = cast(T_DataArray, arr.rename(name))
#     710     datasets.append(arr._to_temp_dataset())
# --> 712 ds = _dataset_concat(
#     713     datasets,
#     714     dim,
#     715     data_vars,
#     716     coords,
#     717     compat,
#     718     positions,
#     719     fill_value=fill_value,
#     720     join=join,
#     721     combine_attrs=combine_attrs,
#     722 )
#     724 merged_attrs = merge_attrs([da.attrs for da in arrays], combine_attrs)
#     726 result = arrays[0]._from_temp_dataset(ds, name)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/concat.py:630, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     628         result_vars[k] = v
#     629 else:
# --> 630     combined_var = concat_vars(
#     631         vars, dim, positions, combine_attrs=combine_attrs
#     632     )
#     633     # reindex if variable is not present in all datasets
#     634     if len(variable_index) < concat_index_size:
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/variable.py:3260, in concat(variables, dim, positions, shortcut, combine_attrs)
#    3258     return IndexVariable.concat(variables, dim, positions, shortcut, combine_attrs)
#    3259 else:
# -> 3260     return Variable.concat(variables, dim, positions, shortcut, combine_attrs)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/variable.py:2113, in Variable.concat(cls, variables, dim, positions, shortcut, combine_attrs)
#    2111 axis = first_var.get_axis_num(dim)
#    2112 dims = first_var_dims
# -> 2113 data = duck_array_ops.concatenate(arrays, axis=axis)
#    2114 if positions is not None:
#    2115     # TODO: deprecate this option -- we don't need it for groupby
#    2116     # any more.
#    2117     indices = nputils.inverse_permutation(np.concatenate(positions))
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:326, in concatenate(arrays, axis)
#     324     xp = get_array_namespace(arrays[0])
#     325     return xp.concat(as_shared_dtype(arrays, xp=xp), axis=axis)
# --> 326 return _concatenate(as_shared_dtype(arrays), axis=axis)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:205, in as_shared_dtype(scalars_or_arrays, xp)
#     203     arrays = [asarray(x, xp=cp) for x in scalars_or_arrays]
#     204 else:
# --> 205     arrays = [asarray(x, xp=xp) for x in scalars_or_arrays]
#     206 # Pass arrays directly instead of dtypes to result_type so scalars
#     207 # get handled properly.
#     208 # Note that result_type() safely gets the dtype from dask arrays without
#     209 # evaluating them.
#     210 out_type = dtypes.result_type(*arrays)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:205, in <listcomp>(.0)
#     203     arrays = [asarray(x, xp=cp) for x in scalars_or_arrays]
#     204 else:
# --> 205     arrays = [asarray(x, xp=xp) for x in scalars_or_arrays]
#     206 # Pass arrays directly instead of dtypes to result_type so scalars
#     207 # get handled properly.
#     208 # Note that result_type() safely gets the dtype from dask arrays without
#     209 # evaluating them.
#     210 out_type = dtypes.result_type(*arrays)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/duck_array_ops.py:192, in asarray(data, xp)
#     191 def asarray(data, xp=np):
# --> 192     return data if is_duck_array(data) else xp.asarray(data)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:693, in MemoryCachedArray.__array__(self, dtype)
#     692 def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
# --> 693     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:696, in MemoryCachedArray.get_duck_array(self)
#     695 def get_duck_array(self):
# --> 696     self._ensure_cached()
#     697     return self.array.get_duck_array()
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:690, in MemoryCachedArray._ensure_cached(self)
#     689 def _ensure_cached(self):
# --> 690     self.array = as_indexable(self.array.get_duck_array())
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:664, in CopyOnWriteArray.get_duck_array(self)
#     663 def get_duck_array(self):
# --> 664     return self.array.get_duck_array()
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:551, in LazilyIndexedArray.get_duck_array(self)
#     550 def get_duck_array(self):
# --> 551     array = self.array[self.key]
#     552     # self.array[self.key] is now a numpy array when
#     553     # self.array is a BackendArray subclass
#     554     # and self.key is BasicIndexer((slice(None, None, None),))
#     555     # so we need the explicit check for ExplicitlyIndexed
#     556     if isinstance(array, ExplicitlyIndexed):
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/coding/variables.py:112, in NativeEndiannessArray.__getitem__(self, key)
#     111 def __getitem__(self, key) -> np.ndarray:
# --> 112     return np.asarray(self.array[key], dtype=self.dtype)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:471, in ExplicitlyIndexedNDArrayMixin.__array__(self, dtype)
#     468 def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
#     469     # This is necessary because we apply the indexing key in self.get_duck_array()
#     470     # Note this is the base class for all lazy indexing classes
# --> 471     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/coding/variables.py:74, in _ElementwiseFunctionArray.get_duck_array(self)
#      73 def get_duck_array(self):
# ---> 74     return self.func(self.array.get_duck_array())
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:551, in LazilyIndexedArray.get_duck_array(self)
#     550 def get_duck_array(self):
# --> 551     array = self.array[self.key]
#     552     # self.array[self.key] is now a numpy array when
#     553     # self.array is a BackendArray subclass
#     554     # and self.key is BasicIndexer((slice(None, None, None),))
#     555     # so we need the explicit check for ExplicitlyIndexed
#     556     if isinstance(array, ExplicitlyIndexed):
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/backends/pydap_.py:48, in PydapArrayWrapper.__getitem__(self, key)
#      47 def __getitem__(self, key):
# ---> 48     return indexing.explicit_indexing_adapter(
#      49         key, self.shape, indexing.IndexingSupport.BASIC, self._getitem
#      50     )
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/core/indexing.py:858, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     836 """Support explicit indexing by delegating to a raw indexing method.
#     837
#     838 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     855 Indexing result, in the form of a duck numpy-array.
#     856 """
#     857 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 858 result = raw_indexing_method(raw_key.tuple)
#     859 if numpy_indices.tuple:
#     860     # index the loaded np.ndarray
#     861     result = NumpyIndexingAdapter(result)[numpy_indices]
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/backends/pydap_.py:56, in PydapArrayWrapper._getitem(self, key)
#      52 def _getitem(self, key):
#      53     # pull the data from the array attribute if possible, to avoid
#      54     # downloading coordinate data twice
#      55     array = getattr(self.array, "array", self.array)
# ---> 56     result = robust_getitem(array, key, catch=ValueError)
#      57     result = np.asarray(result)
#      58     # in some cases, pydap doesn't squeeze axes automatically like numpy
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/xarray/backends/common.py:73, in robust_getitem(array, key, catch, max_retries, initial_delay)
#      71 for n in range(max_retries + 1):
#      72     try:
# ---> 73         return array[key]
#      74     except catch:
#      75         if n == max_retries:
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/model.py:339, in BaseType.__getitem__(self, index)
#     337 def __getitem__(self, index):
#     338     out = copy.copy(self)
# --> 339     out.data = self._get_data_index(index)
#     340     if type(self.data).__name__ == "BaseProxyDap4":
#     341         out.attributes["checksum"] = self.data.checksum
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/model.py:371, in BaseType._get_data_index(self, index)
#     369     return np.vectorize(decode_np_strings)(self._data[index])
#     370 else:
# --> 371     return self._data[index]
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/handlers/dap.py:405, in BaseProxyDap2.__getitem__(self, index)
#     403 # Parse received dataset:
#     404 dataset = dds_to_dataset(dds)
# --> 405 dataset.data = unpack_dap2_data(BytesReader(data), dataset)
#     406 return dataset[self.id].data
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/handlers/dap.py:770, in unpack_dap2_data(xdr_stream, dataset)
#     768 def unpack_dap2_data(xdr_stream, dataset):
#     769     """Unpack a string of encoded data, returning data as lists."""
# --> 770     return unpack_children(xdr_stream, dataset)
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/handlers/dap.py:696, in unpack_children(stream, template)
#     694     out.append(IterData(list(unpack_sequence(stream, col)), col))
#     695 elif isinstance(col, StructureType):
# --> 696     out.append(tuple(unpack_children(stream, col)))
#     698 # unpack arrays
#     699 else:
#     700     out.extend(convert_stream_to_list(stream, col.dtype, col.shape, col.id))
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/handlers/dap.py:700, in unpack_children(stream, template)
#     696         out.append(tuple(unpack_children(stream, col)))
#     698     # unpack arrays
#     699     else:
# --> 700         out.extend(convert_stream_to_list(stream, col.dtype, col.shape, col.id))
#     701 return out
#
# File ~/miniconda3/envs/py3_std/lib/python3.9/site-packages/pydap/handlers/dap.py:725, in convert_stream_to_list(stream, parser_dtype, shape, id)
#     722 stream.read(4)  # read additional length
#     723 try:
#     724     out.append(
# --> 725         numpy.frombuffer(stream.read(count), response_dtype)
#     726         .astype(parser_dtype)
#     727         .reshape(shape)
#     728     )
#     729 except ValueError as e:
#     730     if str(e) == "total size of new array must be unchanged":
#     731         # server-side failure.
#     732         # it is expected that the user should be mindful of this:
#
# ValueError: buffer size must be a multiple of element size

# %%
#path_oi = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2/'
#path_oi = 'http://psl.noaa.gov/thredds/dodsC/Datasets/noaa.oisst.v2.highres/'
#(ssta_atl3_norm_oi,ssta_aba_norm_oi,
# ssta_nino34_norm_oi,ssta_dni_norm_oi,
# ssta_cni_norm_oi,ssta_nni_norm_oi,iod_index) = read_data_compute_anomalies_oi(path_oi)

# %%
path_ersstv5 = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.ersst.v5/sst.mnmean.nc'
(ssta_atl3_norm_ersst,ssta_aba_norm_ersst,
 ssta_nino34_norm_ersst,ssta_dni_norm_ersst,
 ssta_cni_norm_ersst,ssta_nni_norm_ersst,iod_ersst) = read_data_compute_anomalies_ersstv5(path_ersstv5)

# %% [markdown]
# # Timeseries of SST anomalies

# %% [markdown]
# # Monthly data <a id='monthly'></a>

# %% [markdown]
# # [COBE SST](https://psl.noaa.gov/data/gridded/data.cobe.html) | 1$^{\circ}$ x 1$^{\circ}$ | Monthly

# %%
plot_anomalies(ssta_atl3_norm_cobe,
               ssta_aba_norm_cobe,
               ssta_nino34_norm_cobe,
               ssta_dni_norm_cobe,
               ssta_cni_norm_cobe,
               ssta_nni_norm_cobe)

# %% [markdown]
# # [OI SST v2](https://psl.noaa.gov/data/gridded/data.noaa.oisst.v2.html) | 1$^{\circ}$ x 1$^{\circ}$ | Monthly

# %%
#plot_anomalies(ssta_atl3_norm_oi,
#               ssta_aba_norm_oi,
#               ssta_nino34_norm_oi,
#               ssta_dni_norm_oi,
#               ssta_cni_norm_oi,
#               ssta_nni_norm_oi)

# %% [markdown]
# # [ERSST V5](https://psl.noaa.gov/data/gridded/data.noaa.ersst.v5.html) | 2$^{\circ}$ x 2$^{\circ}$ | Monthly

# %%
plot_anomalies(ssta_atl3_norm_ersst,
               ssta_aba_norm_ersst,
               ssta_nino34_norm_ersst,
               ssta_dni_norm_ersst,
               ssta_cni_norm_ersst,
               ssta_nni_norm_ersst)

# %% [markdown]
# # ATL4 zonal wind <a id='monthly_u'></a>

# %% [markdown]
# # [NCEP-V1](https://psl.noaa.gov/data/gridded/data.ncep.reanalysis.html) | 2 x 2 | Monthly

# %%
ncep_data = 'https://psl.noaa.gov/thredds/dodsC/Datasets/ncep.reanalysis/Monthlies/surface/uwnd.mon.mean.nc'
uwnda_atl4_norm = read_compute_anomalies_uwind_plot(ncep_data)
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 144, time: 937, lat: 73)
# Coordinates:
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 1948-01-01 1948-02-01 ... 2026-01-01
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
# Data variables:
#     uwnd     (time, lat, lon) float32 ...
# Attributes:
#     description:                     Data from NCEP initialized reanalysis (4...
#     platform:                        Model
#     Conventions:                     COARDS
#     NCO:                             20121012
#     history:                         Thu May  4 20:11:28 2000: ncrcat -d time...
#     title:                           monthly mean uwnd.sig995 from the NCEP R...
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.2,hdf5=1.8.20
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# # WAMOI: West African Monsoon onset index from 2000 to present day
# <a id='test'></a>

# %% [markdown]
# Methodology inspired from : Fontaine and Louvet (2006)
#
#
#  # WAMOI = NI$_{std}$ - SI$_{std}$
#  - with NI being the precipitation averaged over 7.5$^\circ$N-20$^\circ$N; 10$^\circ$W-10$^\circ$E
#  - and with SI the precipitation averaged over 0$^\circ$N-7.5$^\circ$N; 10$^\circ$W-10$^\circ$E
#
#  --> NI and SI are then standardized i.e. NI$_{std}$ = NI/(std(NI))
#
#  --> a 5-pentad running mean is then apply to the WAMOI time series
#
#
#
# ### On the following plot, yearly WAMOI is plotted (grey lines), the mean of the WAMOI over the period 2000-2021 (black line) as well as the current year WAMOI(red line).

# %% [markdown]
# # [CPC Merged Analysis of Precipitation](https://psl.noaa.gov/data/gridded/data.cmap.html) | 2.5$^{\circ}$ x 2.5$^{\circ}$ | Weekly

# %%
path_cmap = 'http://psl.noaa.gov/thredds/dodsC/Datasets/cmap/rt/precip.pentad.mean.rt.nc'
plot_wamoi(path_cmap)
# Out:
# (26, 73)

# %% [markdown]
# # Atlantic Cold Tongue Onset | Caniaux et al., (2011) | Weekly <a id='test3'></a>

# %% [markdown]
# Sact  = $\int_{A(x)} He(25^{\circ}C-SST(x))dA$
#
# where He is the Heaviside function (He = 1 when SST < 25$^{\circ}$C
# and 0 otherwise). The SST index expresses the intensity of the
# cooling in the ACT and is defined point by point by subtracting
# the SST for each grid point from a SST of 25$^{\circ}$C
# (so that SSTs below 25$^{\circ}$C imply a positive index) inside
# the domain A, 30$^{\circ}$W–12$^{\circ}$E and 5$^{\circ}$S–5$^{\circ}$N.

# %%
path_ersstv5 = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.ersst.v5/'
sst = read_data_ACT_week_plot_ersstv5(path_ersstv5)

# %% [markdown]
# # [Atlantic Meridional mode](https://www.aos.wisc.edu/~dvimont/MModes/AMM.html) | Chiang and Vimont (2004) | Monthly  <a id='test2'></a>

# %% [markdown]
# The realtime AMM index is defined following the method of Chiang and Vimont (2004). The AMM spatial structure is defined via applying Maximum Covariance Analysis (MCA; Bretherton et al. 1992) is to tropical Atlantic SST and 10m winds over ocean regions between 75E and 15W, 21S to 32N. Data are obtained from the NCEP-NCAR Reanalysis (Kalnay et al. 1996), from NOAA ESRL. The spatial resolution is reduced by averaging three points in the zonal direction, and two points in the latitudinal direction, resulting in approximately 3.8deg latitude by 5.6deg longitude resolution over the region. Next, the seasonal cycle is removed, data are detrended, a three month running mean is applied to the data, and the equatorial Pacific Cold Tongue Index (SST averaged over 180-90W, 6S-6N) is removed (via linear regression) from all points. Finally, the data are weighted by the square root of the cosine of latitude, and the covariance matrix is formed between SST and winds (note the wind fields are appended to each other so the wind state vector has twice as many points as the SST state vector). The covariance matrix is decomposed via Singular Value Decomposition, and the leading statistical mode form the AMM SST and Wind patterns. The time period over which the patterns are computed is frozen as the 1950-2005 time period so that the patterns do not change as the index is being updated.

# %%
data_amm = 'https://psl.noaa.gov/data/timeseries/monthly/AMM/ammsst.data'
amm_plot_new(data_amm)

# %% [markdown]
# # [Atlantic Multi-decadal Oscillation](https://psl.noaa.gov/data/timeseries/AMO/) | Monthly <a id='test4'></a>

# %%
#data_amo= 'https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/index/ersst.v5.amo.dat'
#plot_amo_new(data_amo)

# %% [markdown]
# # [St Helena index](https://psl.noaa.gov/data/gridded/data.ncep.reanalysis.derived.html) (SLP based 3-month running mean) | Monthly <a id='test5'></a>

# %%
ncep_data_slp = 'https://psl.noaa.gov/thredds/dodsC/Datasets/ncep.reanalysis.derived/surface/slp.mon.mean.nc'
plot_slp(ncep_data_slp)

# %% [markdown]
# # Indian Ocean Dipole index  <a id='test7'></a>

# %% [markdown]
# ### COBE-SST

# %%
plot_IOD(iod_cobe)

# %% [markdown]
# ### ERSST v5

# %%
plot_IOD(iod_ersst)

# %% [markdown]
# # Identification of Atlantic Niños/Niños and Benguela Niños/Niñas <a id='test9'></a>

# %% [markdown]
# ### Atlantic Niño events since 1982

# %%
_,_,table_atl3_w,table_atl3_c = create_table_event(ssta_atl3_norm_ersst)
table_atl3_w
# Out:
#    Start date End date  Duration  Mean SSTa  Cumul SSTa  Max SSTa  \
# 0     1984-06  1984-10         4       1.56        6.25      2.12
# 1     1987-06  1987-10         4       1.94        7.74      2.80
# 2     1988-03  1988-09         6       2.14       12.83      3.09
# 3     1989-06  1989-10         4       1.16        4.64      1.29
# 4     1993-09  1994-01         4       1.38        5.53      2.05
# 5     1995-05  1995-08         3       1.42        4.27      1.54
# 6     1996-05  1996-08         3       1.75        5.26      2.50
# 7     1997-12  1998-03         3       1.48        4.43      1.57
# 8     1998-06  1998-09         3       1.29        3.86      1.57
# 9     2016-10  2017-01         3       1.24        3.71      1.45
# 10    2019-11  2020-03         4       2.17        8.70      2.44
# 11    2021-06  2021-10         4       2.09        8.35      2.53
# 12    2024-02  2024-05         3       2.18        6.55      2.77
#
#    Date max SSTa
# 0     1984-09-01
# 1     1987-07-01
# 2     1988-07-01
# 3     1989-08-01
# 4     1993-11-01
# 5     1995-06-01
# 6     1996-06-01
# 7     1998-01-01
# 8     1998-06-01
# 9     2016-11-01
# 10    2020-01-01
# 11    2021-07-01
# 12    2024-03-01

# %% [markdown]
# ### Atlantic Niña events since 1982

# %%
table_atl3_c
# Out:
#    Start date End date  Duration  Mean SSTa  Cumul SSTa  Max SSTa  \
# 0     1982-06  1982-10         4      -1.46       -5.83     -1.84
# 1     1991-10  1992-02         4      -1.47       -5.89     -1.90
# 2     1992-04  1992-10         6      -1.76      -10.55     -2.48
# 3     1996-11  1997-08         9      -1.66      -14.93     -2.63
# 4     2000-06  2000-12         6      -1.26       -7.53     -1.31
# 5     2001-11  2002-02         3      -1.87       -5.61     -2.41
# 6     2004-04  2004-07         3      -1.38       -4.15     -1.59
# 7     2005-05  2005-08         3      -2.57       -7.71     -3.22
# 8     2009-07  2009-12         5      -1.32       -6.62     -1.68
# 9     2011-12  2012-08         8      -1.65      -13.16     -2.00
# 10    2013-07  2014-01         6      -1.27       -7.60     -1.50
# 11    2015-06  2015-09         3      -1.18       -3.54     -1.38
#
#                     Date max SSTa
# 0   1982-07-01T00:00:00.000000000
# 1   1991-11-01T00:00:00.000000000
# 2   1992-05-01T00:00:00.000000000
# 3   1997-06-01T00:00:00.000000000
# 4   2000-11-01T00:00:00.000000000
# 5   2001-12-01T00:00:00.000000000
# 6   2004-04-01T00:00:00.000000000
# 7   2005-06-01T00:00:00.000000000
# 8   2009-08-01T00:00:00.000000000
# 9   2012-02-01T00:00:00.000000000
# 10  2013-09-01T00:00:00.000000000
# 11  2015-08-01T00:00:00.000000000

# %% [markdown]
# ### Benguela Niño events since 1982

# %%
_,_,table_aba_w,table_aba_c = create_table_event(ssta_aba_norm_ersst)
table_aba_w
# Out:
#   Start date End date  Duration  Mean SSTa  Cumul SSTa  Max SSTa Date max SSTa
# 0    1984-02  1984-10         8       2.27       18.15      3.00    1984-03-01
# 1    1991-05  1991-08         3       1.75        5.25      2.44    1991-05-01
# 2    1994-10  1995-01         3       1.36        4.09      1.51    1994-10-01
# 3    1995-02  1995-06         4       2.56       10.23      3.35    1995-04-01
# 4    1996-03  1996-07         4       1.59        6.34      2.28    1996-04-01
# 5    1997-10  1998-02         4       1.54        6.15      1.75    1997-12-01
# 6    2011-01  2011-05         4       1.77        7.06      1.92    2011-03-01
# 7    2019-11  2020-02         3       1.79        5.36      2.21    2019-11-01
# 8    2021-05  2021-09         4       1.79        7.17      2.22    2021-06-01
# 9    2023-11  2024-03         4       1.42        5.69      1.94    2023-12-01

# %% [markdown]
# ### Benguela Niña events since 1982

# %%
table_aba_c
# Out:
#   Start date End date  Duration  Mean SSTa  Cumul SSTa  Max SSTa  \
# 0    1983-03  1983-08         5      -1.42       -7.12     -1.86
# 1    1991-11  1992-02         3      -1.09       -3.26     -1.15
# 2    1992-03  1992-09         6      -1.52       -9.10     -1.82
# 3    1996-11  1997-07         8      -1.98      -15.85     -3.05
# 4    2001-12  2002-03         3      -1.42       -4.26     -1.88
# 5    2004-03  2004-06         3      -2.25       -6.76     -3.11
# 6    2005-04  2005-10         6      -1.56       -9.35     -2.63
# 7    2010-02  2010-05         3      -1.47       -4.42     -1.83
# 8    2011-06  2011-09         3      -1.11       -3.34     -1.19
# 9    2011-11  2012-04         5      -1.74       -8.69     -2.39
#
#                    Date max SSTa
# 0  1983-04-01T00:00:00.000000000
# 1  1991-11-01T00:00:00.000000000
# 2  1992-03-01T00:00:00.000000000
# 3  1997-03-01T00:00:00.000000000
# 4  2002-01-01T00:00:00.000000000
# 5  2004-04-01T00:00:00.000000000
# 6  2005-05-01T00:00:00.000000000
# 7  2010-04-01T00:00:00.000000000
# 8  2011-08-01T00:00:00.000000000
# 9  2012-01-01T00:00:00.000000000

# %% [markdown]
# # Canonical/Non-canonical Atlantic Niños <a id='test6'></a>

# %% [markdown]
# Figure inspired by the Richter et al., (2013), in which they identify some warm events that can not be explained by previously identify equatorial wind stress forcing.
#
# --> A warm SST event is categorized as a canonical (non-canonical) event when it is preceded by a
# positive (negative) surface wind anomaly. Hence, canonical events lie in the upper right (in red) and lower left (in blue), and non-canonical events lie in the upper left and lower right (in black) quadrants.

# %%
plot_canonical_atlantic_ninos(uwnda_atl4_norm,ssta_atl3_norm_ersst)

# %% [markdown]
# # [Forecast from CFSv2 next three month](https://www.cpc.ncep.noaa.gov/products/CFSv2/CFSv2_body.html) <a id='test8'></a>

# %% [markdown]
# # +1 month

# %%
Image(url='https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd2.gif')
# Out:
# <img src="https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd2.gif"/>

# %% [markdown]
# # +2 month

# %%
Image(url='https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd3.gif')
# Out:
# <img src="https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd3.gif"/>

# %% [markdown]
# # +3 Month

# %%
Image(url='https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd4.gif')
# Out:
# <img src="https://www.cpc.ncep.noaa.gov/products/CFSv2/imagesInd3/glbSSTMonInd4.gif"/>

# %% [markdown]
# # Last days SST anomalies

# %%
Image(url='https://climatereanalyzer.org/wx/todays-weather/maps/gfs_world-wt_sstanom_d1.png')
# Out:
# <img src="https://climatereanalyzer.org/wx/todays-weather/maps/gfs_world-wt_sstanom_d1.png"/>

# %% [markdown]
# # Last days SST

# %%
Image(url='https://climatereanalyzer.org/wx/todays-weather/maps/gfs_world-wt_sst_d1.png')
# Out:
# <img src="https://climatereanalyzer.org/wx/todays-weather/maps/gfs_world-wt_sst_d1.png"/>

# %% [markdown]
# # [Animations from the CPC](https://www.cpc.ncep.noaa.gov/products/GODAS/background.shtml)

# %% [markdown]
# # [Subsurface temperature anomalies](https://www.cpc.ncep.noaa.gov/products/GODAS/)

# %%
Image(url='https://www.cpc.ncep.noaa.gov/products/GODAS/pent_gif/xz/movie.temp.0n.gif',width=800)
# Out:
# <img src="https://www.cpc.ncep.noaa.gov/products/GODAS/pent_gif/xz/movie.temp.0n.gif" width="800"/>

# %% [markdown]
# # [Z20 anomalies](https://www.cpc.ncep.noaa.gov/products/GODAS/)

# %%
Image(url='https://www.cpc.ncep.noaa.gov/products/GODAS/pent_gif/xy/movie.d20.gif',width=800)
# Out:
# <img src="https://www.cpc.ncep.noaa.gov/products/GODAS/pent_gif/xy/movie.d20.gif" width="800"/>

# %% [markdown]
# # References <a id='test20'></a>

# %% [markdown]
# - Caniaux, G., H. Giordani, J.‐L. Redelsperger, F. Guichard, E. Key, and M. Wade (2011), Coupling between the Atlantic cold tongue and the West African monsoon in boreal spring and summer, J. Geophys. Res., 116, C04003,
# doi:10.1029/2010JC006570.
# - Chiang, J. C. H., & Vimont, D. J. (2004). Analogous Pacific and Atlantic Meridional Modes of Tropical Atmosphere–Ocean Variability, Journal of Climate, 17(21), 4143-4158.
# - Enfield, D.B., A.M. Mestas-Nunez, and P.J. Trimble, 2001: The Atlantic Multidecadal Oscillation and its relationship to rainfall and river flows in the continental U.S., Geophys. Res. Lett., 28: 2077-2080.
# - Fontaine, B., and S. Louvet (2006), Sudan-Sahel rainfall onset: Definition of an objective index, types of years, and experimental hindcasts, J. Geophys. Res., 111, D20103, doi:10.1029/2005JD007019.
# - Richter, I., Behera, S., Masumoto, Y. et al. Multiple causes of interannual sea surface temperature variability in the equatorial Atlantic Ocean. Nature Geosci 6, 43–47 (2013). https://doi.org/10.1038/ngeo1660
